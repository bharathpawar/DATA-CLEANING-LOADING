# %%
import pandas as pd

# %%
df1=pd.read_csv(r"/users/pawarbharath/downloads/drive/nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  06-May   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0  06-Oct   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 452            NaN             NaN     NaN      NaN   NaN     NaN     NaN
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  06-Mar   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0  06-Jan   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0  07-Mar   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0     7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.sort_values('Name')
# Out:
#                Name                    Team  Number Position   Age  Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0  06-Sep
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0  06-Jun
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0  06-Oct
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0  06-Oct
# ..              ...                     ...     ...      ...   ...     ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0  06-Mar
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0  06-May
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0  06-Sep
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0  06-Nov
# 452             NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# ...

# %%
df.sort_values('Team')
# Out:
#                  Name                Team  Number Position   Age  Height  \
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0  06-May
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0  06-May
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0  06-Jun
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0  06-Apr
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0  06-Oct
# ..                ...                 ...     ...      ...   ...     ...
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0  06-Jul
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0  06-Jun
# 382         John Wall  Washington Wizards     2.0       PG  25.0  06-Apr
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0  06-May
# 452               NaN                 NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# 317   225.0      Pittsburgh    525093.0
# ...

# %%
df.sort_values('Name',ascending=False)
# Out:
#                 Name                    Team  Number Position   Age  Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0  06-Nov
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0  06-Sep
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0  06-May
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0  06-Mar
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0  06-Aug
# ..               ...                     ...     ...      ...   ...     ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0  06-Oct
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0  06-Jun
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0  06-Sep
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
# 452              NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# ...

# %%
df.sort_values('Team',ascending=True)
# Out:
#                  Name                Team  Number Position   Age  Height  \
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0  06-May
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0  06-May
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0  06-Jun
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0  06-Apr
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0  06-Oct
# ..                ...                 ...     ...      ...   ...     ...
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0  06-Jul
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0  06-Jun
# 382         John Wall  Washington Wizards     2.0       PG  25.0  06-Apr
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0  06-May
# 452               NaN                 NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# 317   225.0      Pittsburgh    525093.0
# ...

# %%
df.sort_values('Team',ascending=False)
# Out:
#                  Name                Team  Number Position   Age  Height  \
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0  06-May
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0  06-Jun
# 381   Marcus Thornton  Washington Wizards    15.0       SF  29.0  06-Apr
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0  06-Jun
# 379    Ramon Sessions  Washington Wizards     7.0       PG  30.0  06-Mar
# ..                ...                 ...     ...      ...   ...     ...
# 313    Kris Humphries       Atlanta Hawks    43.0       PF  31.0  06-Sep
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0  06-Oct
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0  06-Apr
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0  06-Jun
# 452               NaN                 NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# 369   207.0         Florida   5694674.0
# ...

# %%
df.sort_values('Age',ascending=False)
# Out:
#                Name                    Team  Number Position   Age  Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0  06-Mar
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0  06-Nov
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0  06-Nov
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0  06-Jun
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0  06-Mar
# ..              ...                     ...     ...      ...   ...     ...
# 56    Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0  06-Nov
# 60   Christian Wood      Philadelphia 76ers    35.0       PF  20.0  06-Nov
# 226   Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0  06-Jun
# 122    Devin Booker            Phoenix Suns     1.0       SG  19.0  06-Jun
# 452             NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight         College     Salary
# ...

# %%
df1.sort_values('Salary',ascending=False)
# Out:
#                 Name                    Team  Number Position   Age  Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0  06-Jun
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0  06-Aug
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0  06-Aug
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0  06-Nov
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0  06-Nov
# ..               ...                     ...     ...      ...   ...     ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0  06-Feb
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0  06-Sep
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0  06-Jul
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0  06-Oct
# 452              NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight                College      Salary
# ...

# %%
df1.sort_values(['Salary','Age'],ascending=[False,False])
# Out:
#                 Name                 Team  Number Position   Age  Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0  06-Jun
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0  06-Aug
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0  06-Aug
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0  06-Nov
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0  06-Nov
# ..               ...                  ...     ...      ...   ...     ...
# 269     Ray McCallum    Memphis Grizzlies     5.0       PG  24.0  06-Mar
# 270   Xavier Munford    Memphis Grizzlies    14.0       PG  24.0  06-Mar
# 350    Briante Weber           Miami Heat    12.0       PG  23.0  06-Feb
# 397     Axel Toupane       Denver Nuggets     6.0       SG  23.0  06-Jul
# 452              NaN                  NaN     NaN      NaN   NaN     NaN
#
#      Weight                College      Salary
# ...

# %%
df1.sort_values(['Name','Team','Age'],ascending=[True,False,False])
# Out:
#                Name                    Team  Number Position   Age  Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0  06-Sep
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0  06-Jun
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0  06-Oct
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0  06-Oct
# ..              ...                     ...     ...      ...   ...     ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0  06-Mar
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0  06-May
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0  06-Sep
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0  06-Nov
# 452             NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# ...

# %%
df.sort_values(['Name','Team','Age'],ascending=[True,False,False],ignore_index=[True])
# Out:
#                Name                    Team  Number Position   Age  Height  \
# 0      Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
# 1      Aaron Gordon           Orlando Magic     0.0       PF  20.0  06-Sep
# 2    Aaron Harrison       Charlotte Hornets     9.0       SG  21.0  06-Jun
# 3     Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0  06-Oct
# 4        Al Horford           Atlanta Hawks    15.0        C  30.0  06-Oct
# ..              ...                     ...     ...      ...   ...     ...
# 452  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0  06-Mar
# 453     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0  06-May
# 454   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0  06-Sep
# 455   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0  06-Nov
# 456             NaN                     NaN     NaN      NaN   NaN     NaN
#
#      Weight         College      Salary
# ...

# %%
df1.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df=pd.read_csv(r"/users/pawarbharath/downloads/drive/employees.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
df['Last Login Time']=pd.to_datetime(df['Last Login Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
def add_features(df):
    df['year']=df['Start Date'].dt.year
    df['month']=df['Start Date'].dt.month
    df['day']=df['Start Date'].dt.day

# %%
add_features(df)

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-08-11 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-08-11 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-08-11 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-08-11 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-11 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-08-11 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-11 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-11 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-11 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-08-11 18:24:00  129949   10.169
#
#     Senior Management                  Team  year  month  day
# ...

# %%
def add_features1(df):
    df['hour']=df['Last Login Time'].dt.hour
    df['minute']=df['Last Login Time'].dt.minute
    df['second']=df['Last Login Time'].dt.second

# %%
add_features1(df)

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-08-11 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-08-11 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-08-11 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-08-11 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-11 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-08-11 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-11 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-11 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-11 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-08-11 18:24:00  129949   10.169
#
#     Senior Management                  Team  year  month  day  hour  minute  \
# ...
