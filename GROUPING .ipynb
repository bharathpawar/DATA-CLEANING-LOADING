# %%
import pandas as pd

# %%
df=pd.read_csv(r"/users/pawarbharath/downloads/drive/fortune1000.csv")

# %%
df.head(10)
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
sectors=df.groupby('Sector')

# %%
len(sectors)
# Out:
# 21

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(df)
# Out:
# 1000

# %%
df.groupby('Sector')

# %%
df['Sector'].nunique()
# Out:
# 21

# %%
df['Sector'].unique()
# Out:
# array(['Retailing', 'Energy', 'Technology', 'Financials', 'Health Care',
#        'Food and Drug Stores', 'Motor Vehicles & Parts',
#        'Telecommunications', 'Industrials', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Wholesalers', 'Apparel',
#        'Hotels, Resturants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
df['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Hotels, Resturants & Leisure     25
# Media                            25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Apparel                          15
# Telecommunications               15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
industry=df.groupby('Industry')

# %%
industry.size()
# Out:
# Industry
# Advertising, marketing                             2
# Aerospace and Defense                             20
# Airlines                                           9
# Apparel                                           15
# Automotive Retailing, Services                    10
# Beverages                                          9
# Building Materials, Glass                          7
# Chemicals                                         30
# Commercial Banks                                  28
# Computer Peripherals                               4
# Computer Software                                 14
# Computers, Office Equipment                        7
# Construction and Farm Machinery                    9
# Diversified Financials                            15
# Diversified Outsourcing Services                  14
# Education                                          3
# Electronics, Electrical Equip.                    13
# ...

# %%
industry.size()
# Out:
# Industry
# Advertising, marketing                             2
# Aerospace and Defense                             20
# Airlines                                           9
# Apparel                                           15
# Automotive Retailing, Services                    10
# Beverages                                          9
# Building Materials, Glass                          7
# Chemicals                                         30
# Commercial Banks                                  28
# Computer Peripherals                               4
# Computer Software                                 14
# Computers, Office Equipment                        7
# Construction and Farm Machinery                    9
# Diversified Financials                            15
# Diversified Outsourcing Services                  14
# Education                                          3
# Electronics, Electrical Equip.                    13
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.get_group('Energy')['Revenue'].sum()
# Out:
# 1517809

# %%
sectors.get_group('Retailing')['Employees'].sum()
# Out:
# 6227629

# %%
sectors['Profits'].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -73447
# Engineering & Construction        5304
# Financials                      260209
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
sectors['Employees'].mean()
# Out:
# Sector
# Aerospace & Defense             48402.850000
# Apparel                         23093.133333
# Business Services               26687.254902
# Chemicals                       15455.033333
# Energy                           9745.303279
# Engineering & Construction      15642.615385
# Financials                      24172.287770
# Food and Drug Stores            93026.533333
# Food, Beverages & Tobacco       28177.488372
# Health Care                     35710.520000
# Hotels, Resturants & Leisure    99369.800000
# Household Products              23072.785714
# Industrials                     33591.934783
# Materials                       14840.069767
# Media                           22012.560000
# Motor Vehicles & Parts          45106.666667
# Retailing                       77845.362500
# Technology                      35087.735294
# Telecommunications              55497.866667
# Transportation                  42688.694444
# Wholesalers                     13139.925000
# ...

# %%
sectors['Employees'].max()
# Out:
# Sector
# Aerospace & Defense              197200
# Apparel                           65300
# Business Services                216500
# Chemicals                         52000
# Energy                            75600
# Engineering & Construction        92000
# Financials                       331000
# Food and Drug Stores             431000
# Food, Beverages & Tobacco        263000
# Health Care                      203500
# Hotels, Resturants & Leisure     505000
# Household Products               110000
# Industrials                      333000
# Materials                         60000
# Media                            185000
# Motor Vehicles & Parts           215000
# Retailing                       2300000
# Technology                       411798
# Telecommunications               281450
# Transportation                   341240
# Wholesalers                       78500
# Name: Employees, dtype: int64

# %%
pd.set_option('display.max_rows',None)

# %%
secind=df.groupby(['Sector','Industry'])
secind.max()
# Out:
#                                                                              Rank  \
# Sector                       Industry
# Aerospace & Defense          Aerospace and Defense                            987
# Apparel                      Apparel                                          917
# Business Services            Advertising, marketing                           355
#                              Diversified Outsourcing Services                 869
#                              Education                                        993
#                              Financial Data Services                          952
#                              Miscellaneous                                    870
#                              Temporary Help                                   951
#                              Waste Management                                 939
# Chemicals                    Chemicals                                        949
# ...

# %%
secind.max()
# Out:
#                                                                    Rank  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           987
# Apparel             Apparel                                         917
# Business Services   Advertising, marketing                          355
#                     Diversified Outsourcing Services                869
#                     Education                                       993
# ...                                                                 ...
# Transportation      Trucking, Truck Leasing                         945
# Wholesalers         Miscellaneous                                   315
#                     Wholesalers: Diversified                        991
#                     Wholesalers: Electronics and Office Equipment   685
#                     Wholesalers: Food and Grocery                   351
#
# ...

# %%
industry.get_group('General Merchandisers')
# Out:
#      Rank         Company     Sector               Industry  \
# 0       1         Walmart  Retailing  General Merchandisers
# 37     38          Target  Retailing  General Merchandisers
# 102   103          Macy’s  Retailing  General Merchandisers
# 110   111  Sears Holdings  Retailing  General Merchandisers
# 138   139  Dollar General  Retailing  General Merchandisers
# 144   145          Kohl’s  Retailing  General Merchandisers
# 196   197       Nordstrom  Retailing  General Merchandisers
# 227   228     J.C. Penney  Retailing  General Merchandisers
# 379   380       Dillard’s  Retailing  General Merchandisers
# 772   773  Bon-Ton Stores  Retailing  General Merchandisers
#
#                 Location  Revenue  Profits  Employees
# 0        Bentonville, AR   482130    14694    2300000
# 37       Minneapolis, MN    73785     3363     341000
# 102       Cincinnati, OH    27079     1072     157500
# 110  Hoffman Estates, IL    25146    -1129     178000
# ...
