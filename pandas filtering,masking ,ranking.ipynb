# %%
import pandas as pd

# %%
df=pd.read_csv(r"/users/pawarbharath/downloads/drive/employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df[df['Gender'] =='Male']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 3        Jerry   Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df_new=df[df['Gender']=='Female']

# %%
df_new.shape
# Out:
# (431, 8)

# %%
df_new.head(2)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 6       Ruby  Female  8/17/1987         4:20 PM   65476   10.012
#
#   Senior Management     Team
# 2             False  Finance
# 6              True  Product

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df[df['Team']=='Finance']
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 46       Bruce    Male  11/28/2009        10:47 PM  114796    6.796
# ..         ...     ...         ...             ...     ...      ...
# 907  Elizabeth  Female   7/27/1998        11:12 AM  137144   10.081
# 954        Joe    Male   1/19/1980         4:06 PM  119667    1.148
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                 NaN  Finance
# ...

# %%
df[df['Team']!='Marketing'].head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
#
#   Senior Management     Team
# 1              True      NaN
# 2             False  Finance
# 3              True  Finance

# %%
df[df['Bonus %']>=5]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# ..         ...     ...         ...             ...     ...      ...
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df[df['Bonus %']>= 5.0 ].head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
#
#   Senior Management       Team
# 0              True  Marketing
# 2             False    Finance
# 3              True    Finance

# %%
df[df['Start Date']>= '4/23/1993' ].head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 6       Ruby  Female  8/17/1987         4:20 PM   65476   10.012
#
#   Senior Management       Team
# 0              True  Marketing
# 2             False    Finance
# 6              True    Product

# %%
df[df['Start Date']>= '11/05/1995' ].head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df[df['Senior Management']==True]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# ..         ...     ...         ...             ...     ...      ...
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
mask1=df['Gender']=='Male'

# %%
mask2=df['Salary']<=101004

# %%
df[mask1&mask2].head(10)
# Out:
#    First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1      Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 4       Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 16     Jeremy   Male  9/21/2010         5:56 AM   90370    7.369
# 21    Matthew   Male   9/5/1995         2:12 AM  100612   13.645
# 24       John   Male   7/1/1992        10:08 PM   97950   13.873
# 25        NaN   Male  10/8/2012         1:12 AM   37076   18.576
# 26      Craig   Male  2/27/2000         7:45 AM   37598    7.757
# 29   Benjamin   Male  1/26/2005        10:06 PM   79529    7.008
# 34      Jerry   Male  1/10/2004        12:56 PM   95734   19.096
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 4               True  Client Services
# 16             False  Human Resources
# 21             False        Marketing
# ...

# %%
mask1=df['Bonus %']>=5
mask2=df['Team']!='Legal'
df[mask1&mask2]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# ..         ...     ...         ...             ...     ...      ...
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df[df['Team']=='Legal'].head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management   Team
# 0              True  Legal
# 1              True  Legal
# 2             False  Legal

# %%
mask3=df['Bonus %']>=5
mask4=df['Team']!='Legal'
df[mask3&mask4]

# %%
maska=df['Gender']=='Male'
maskb=df['Salary']>=100000
df[maska | maskb]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management   Team
# 0                True  Legal
# 1                True  Legal
# 2               False  Legal
# 3                True  Legal
# ...

# %%
maskaa=df['Gender']=='Male'
maskbb=df['Team']=='Finance'
df[maskaa | maskbb]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df=pd.read_csv(r"/users/pawarbharath/downloads/drive/nba.csv")

# %%
df1
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  06-May   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0  06-Oct   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 452            NaN             NaN     NaN      NaN   NaN     NaN     NaN
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  06-Mar   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0  06-Jan   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0  07-Mar   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0     7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df[['Salary']]
# Out:
#         Salary
# 0    7730337.0
# 1    6796117.0
# 2          NaN
# 3    1148640.0
# 4    5000000.0
# ..         ...
# 452        NaN
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
#
# [457 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      456 non-null    object
#  1   Team      456 non-null    object
#  2   Number    456 non-null    float64
#  3   Position  456 non-null    object
#  4   Age       456 non-null    float64
#  5   Height    456 non-null    object
#  6   Weight    456 non-null    float64
#  7   College   372 non-null    object
#  8   Salary    445 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df['Salary']=df['Salary'].fillna(0).astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      456 non-null    object
#  1   Team      456 non-null    object
#  2   Number    456 non-null    float64
#  3   Position  456 non-null    object
#  4   Age       456 non-null    float64
#  5   Height    456 non-null    object
#  6   Weight    456 non-null    float64
#  7   College   372 non-null    object
#  8   Salary    457 non-null    int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 32.3+ KB

# %%
df['Salary'].rank()
# Out:
# 0      361.0
# 1      348.0
# 2        6.5
# 3      137.0
# 4      311.0
#        ...
# 452      6.5
# 453    217.0
# 454     76.0
# 455    243.5
# 456     92.0
# Name: Salary, Length: 457, dtype: float64

# %%
df['salary rank']=df['Salary'].rank(ascending= False).astype(int)

# %%
df.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team  salary rank
# 0              True        Marketing          435
# 1              True              NaN          756
# 2             False          Finance          153
# 3              True          Finance           90
# 4              True  Client Services          400

# %%
df.sort_values('Salary',ascending=False)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# ..         ...     ...        ...             ...     ...      ...
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
# 63     Matthew    Male   1/2/2013        10:33 PM   35203   18.040
# 82      Steven    Male  3/30/1980         9:20 PM   35095    8.379
# 238      Kevin    Male  3/25/1982         7:31 AM   35061    5.128
# 576    Michael    Male  7/30/1993         5:35 PM   35013   14.879
#
#     Senior Management             Team  salary rank
# 644             False          Finance            1
# 429             False  Human Resources            2
# ...

# %%
df.sort_values('salary rank',ascending=True)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# ..         ...     ...        ...             ...     ...      ...
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
# 63     Matthew    Male   1/2/2013        10:33 PM   35203   18.040
# 82      Steven    Male  3/30/1980         9:20 PM   35095    8.379
# 238      Kevin    Male  3/25/1982         7:31 AM   35061    5.128
# 576    Michael    Male  7/30/1993         5:35 PM   35013   14.879
#
#     Senior Management             Team  salary rank
# 644             False          Finance            1
# 429             False  Human Resources            2
# ...

# %%
df['Salary'].rank().astype(int)
# Out:
# 0      361
# 1      348
# 2        6
# 3      137
# 4      311
#       ...
# 452      6
# 453    217
# 454     76
# 455    243
# 456     92
# Name: Salary, Length: 457, dtype: int64

# %%
d8=df['salary rank']=df['Salary'].rank(ascending=False).astype(int)

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College   Salary  salary rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          451

# %%
d6=df.sort_values('salary rank',ascending=True)

# %%
#load data
df['Salary'] = df['Salary'].fillna(0) 
df['Salary Rank'] = df['Salary'].rank(ascending=False).astype(int)
df.sort_values('Salary',ascending=False).head(2)
# Out:
#              Name                 Team  Number Position   Age  Height  Weight  \
# 109   Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0  06-Jun   212.0
# 169  LeBron James  Cleveland Cavaliers    23.0       SF  31.0  06-Aug   250.0
#
#     College    Salary  salary rank  Salary Rank
# 109     NaN  25000000            1            1
# 169     NaN  22970500            2            2

# %%
df2=df.sort_values('Salary',ascending=False).head(2)

# %%
df2
# Out:
#              Name                 Team  Number Position   Age  Height  Weight  \
# 109   Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0  06-Jun   212.0
# 169  LeBron James  Cleveland Cavaliers    23.0       SF  31.0  06-Aug   250.0
#
#     College    Salary  salary rank  Salary Rank
# 109     NaN  25000000            1            1
# 169     NaN  22970500            2            2

# %%
df['Salary Rank'] = df['Salary'].rank(ascending=False).astype(int)

# %%
import pandas as pd

# %%
df5=pd.read_csv(r"/users/pawarbharath/downloads/drive/employees.csv")

# %%
df5.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df5.sort_values(['Salary'],ascending=[False])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# ..         ...     ...        ...             ...     ...      ...
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
# 63     Matthew    Male   1/2/2013        10:33 PM   35203   18.040
# 82      Steven    Male  3/30/1980         9:20 PM   35095    8.379
# 238      Kevin    Male  3/25/1982         7:31 AM   35061    5.128
# 576    Michael    Male  7/30/1993         5:35 PM   35013   14.879
#
#     Senior Management             Team
# 644             False          Finance
# 429             False  Human Resources
# 828             False          Product
# ...

# %%
df5.sort_values('Salary',ascending=False).head(2)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
#
#     Senior Management             Team  Salary Rank
# 644             False          Finance            1
# 429             False  Human Resources            2

# %%
df5['Salary Rank'] = df5['Salary'].rank(ascending=False).astype(int)

# %%
df5.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team  Salary Rank
# 0              True  Marketing          435
# 1              True        NaN          756
# 2             False    Finance          153

# %%
df5.sort_values('Salary Rank',ascending=True).head(2)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
#
#     Senior Management             Team  Salary Rank
# 644             False          Finance            1
# 429             False  Human Resources            2

# %%
mask11=df5['Team']=='Finance' 
mask12=df5['Team']=='Legal'
df5[mask11& mask12
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team, Salary Rank]
# Index: []

# %%
mask13=df5[df5['Team']=='Finance']

# %%
mask13.head(4)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 7         NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 14   Kimberly  Female  1/14/1999         7:13 AM   41426   14.543
#
#    Senior Management     Team  Salary Rank
# 2              False  Finance          153
# 3               True  Finance           90
# 7                NaN  Finance          897
# 14              True  Finance          944

# %%
mask12=df5[df5['Team']=='Legal']

# %%
mask12.head(3)
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
#
#    Senior Management   Team  Salary Rank
# 5              False  Legal          274
# 11              True  Legal          392
# 20              True  Legal          730
