# %%
import pandas as pd

# %%
week1=pd.read_csv(r"/users/pawarbharath/downloads/drive/Restaurant - Week 1 Sales.csv")

# %%
week2=pd.read_csv(r"/users/pawarbharath/downloads/drive/Restaurant - Week 2 Sales.csv")

# %%
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week1.tail()
# Out:
#      Customer ID  Food ID
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10

# %%
week2.head(5)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
con=pd.concat([week1,week2],ignore_index=True)

# %%
con.shape
# Out:
# (500, 2)

# %%
week2.shape
# Out:
# (250, 2)

# %%
pd.set_option('display.max_rows',None)

# %%
con
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# 30           419        7
# 31            20        1
# 32           822        6
# 33           226       10
# ...

# %%
con=pd.concat([week1,week2],keys=['week1','week2'])

# %%
con
# Out:
#            Customer ID  Food ID
# week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
#       5            213        8
#       6            600        1
#       7            503        5
#       8             71        3
#       9            174        3
#       10           961        9
#       11           966        5
#       12           641        4
#       13           288        2
#       14           149        4
#       15           954        2
#       16           147        9
#       17           155        1
#       18           550        6
#       19           101        7
#       20           549        6
#       21            75        6
#       22            78        7
#       23           514        5
#       24           833        7
#       25           329        8
#       26           586       10
#       27           341        1
# ...

# %% [raw]
# append

# %%
week2.append(week1)
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# 30            21        4
# 31           755        7
# 32           509        7
# 33           639        2
# ...

# %%
week2.append(week1)
